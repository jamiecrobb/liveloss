# %%
# Your Jupyter notebook
from liveloss import LiveLoss
from IPython.display import clear_output

import time


l = LiveLoss()

for i in range(30):
    l.send(i, i**2)
    time.sleep(1)

# Keep the last frame displayed after the loop
clear_output(wait=True)
display(l.fig)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 12
#      10 for i in range(30):
#      11     l.send(i, i**2)
# ---> 12     time.sleep(1)
#      14 # Keep the last frame displayed after the loop
#      15 clear_output(wait=True)
#
# KeyboardInterrupt:
